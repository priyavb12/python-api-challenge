# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import json
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from config import weather_api_key  #api_keys

weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# url = 'http://api.openweathermap.org/data/2.5/weather?'

# response_from_api = requests.get(url)

# response_from_api.status_code
# # city = 'dukat'
# # query_url = url + "appid=" + weather_api_key + "&q=" + city

# # weather_response  = requests.get(query_url)
# # weather_json = weather_response.json

# # print(f"The weather API responded with: {weather_json}.")


# assistant icon
# To retrieve weather data from the cities list generated in the starter code using the OpenWeatherMap API, you can follow these steps:

# Make sure you have an API key for the OpenWeatherMap API. If you don't have one, you can sign up on their website to get an API key.

# Import the necessary libraries in your Python script:

# import requests
# import json
# Define your OpenWeatherMap API key and the base URL for the API:
# api_key = 'YOUR_API_KEY'
# base_url = 'http://api.openweathermap.org/data/2.5/weather'
# Iterate through the list of cities and make API requests to retrieve weather data for each city:
# for city in cities:
#     city_name = city['City']
#     city_lat = city['Lat']
#     city_lng = city['Lng']

#     # Create the API request URL for the city
#     url = f"{base_url}?q={city_name}&lat={city_lat}&lon={city_lng}&appid={api_key}"

#     # Send the API request
#     response = requests.get(url)

#     # Check if the request was successful
#     if response.status_code == 200:
#         # Parse the JSON response
#         weather_data = response.json()

#         # Extract the relevant weather information from the response
#         temperature = weather_data['main']['temp']
#         humidity = weather_data['main']['humidity']
#         description = weather_data['weather'][0]['description']

#         # Print or store the weather data as needed
#         print(f"Weather in {city_name}: Temperature - {temperature}K, Humidity - {humidity}%, Description - {description}")
#     else:
#         print(f"Failed to retrieve weather data for {city_name}")

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %%
cities
# Out:
# ['saipan',
#  'dolinsk',
#  'lebu',
#  'blackmans bay',
#  'port-aux-francais',
#  'port lincoln',
#  "arkhangel'sk",
#  'lihue',
#  'grytviken',
#  'kursavka',
#  'yellowknife',
#  'galveston',
#  'ust-nera',
#  'raychikhinsk',
#  'bethel',
#  'tiksi',
#  "mil'kovo",
#  'puerto baquerizo moreno',
#  'iskateley',
#  'adamstown',
#  'yigo village',
#  'edinburgh of the seven seas',
#  'cabo san lucas',
#  'floro',
#  'huayin',
#  'albany',
#  'santo augusto',
#  'otjiwarongo',
#  'badger',
#  'hami',
#  'nejo',
#  'college',
#  'invercargill',
#  'melekeok village',
#  'khandyga',
#  'stanley',
#  'petropavlovsk-kamchatsky',
#  'wailua homesteads',
#  'arish',
#  'amuntai',
#  'ilulissat',
#  'chhor',
#  'port elizabeth',
#  'kodiak',
#  'novaya igirma',
#  'ancud',
#  'namibe',
#  'saint-philippe',
#  'gobindpur',
#  'margaret river',
#  'jamestown',
#  'howard springs',
#  'ambon',
#  "kapa'a",
#  'tazovsky',
#  'troitsko-pechorsk',
#  'darien',
#  'queenstown',
#  'sisimiut',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + '&q=san francisco')
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=88959935e5b3e71115c002a0e0c684d0&q=san francisco

# %%
# Set the API base URL
url =  f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}&q={city}'

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saipan
# City not found. Skipping...
# Processing Record 2 of Set 1 | dolinsk
# City not found. Skipping...
# Processing Record 3 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 4 of Set 1 | blackmans bay
# City not found. Skipping...
# Processing Record 5 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 6 of Set 1 | port lincoln
# City not found. Skipping...
# Processing Record 7 of Set 1 | arkhangel'sk
# City not found. Skipping...
# Processing Record 8 of Set 1 | lihue
# City not found. Skipping...
# Processing Record 9 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 10 of Set 1 | kursavka
# City not found. Skipping...
# Processing Record 11 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 12 of Set 1 | galveston
# City not found. Skipping...
# Processing Record 13 of Set 1 | ust-nera
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
