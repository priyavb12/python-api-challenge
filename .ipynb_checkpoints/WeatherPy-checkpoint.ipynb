# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 578

# %%
cities
# Out:
# ['enkoping',
#  'badger',
#  'hawaiian paradise park',
#  'adamstown',
#  'kapuskasing',
#  'codrington',
#  'minas de marcona',
#  'jindabyne',
#  'brainerd',
#  'port-aux-francais',
#  'east london',
#  'puerto natales',
#  'invercargill',
#  'college',
#  'juegang',
#  'olonkinbyen',
#  'lihue',
#  'lebu',
#  'dudinka',
#  'kodiak',
#  'sola',
#  'edinburgh of the seven seas',
#  'okhotsk',
#  'filadelfia',
#  'laojunmiao',
#  'petropavlovsk-kamchatsky',
#  "vrangel'",
#  'nova sintra',
#  'slivnitsa',
#  'wailua homesteads',
#  'ribeira grande',
#  'grytviken',
#  'papatowai',
#  'avarua',
#  'manturovo',
#  'albany',
#  'gladstone',
#  'bethel',
#  'revda',
#  'iqaluit',
#  'valasske klobouky',
#  'ilulissat',
#  'vadso',
#  'puerto palomas',
#  'trinidad',
#  'port mathurin',
#  'les avirons',
#  'castillos',
#  'haiku-pauwela',
#  'margaret river',
#  "mil'kovo",
#  'blackmans bay',
#  'gadzhiyevo',
#  'abepura',
#  'nabire',
#  "ust'-kut",
#  'waitangi',
#  'al ghayzah',
#  'yellowknife',
#  'floro',
#  'weno',
#  'praia da vitoria',
#  'vorgashor',
#  'fort bragg',
#  'georgetown',
#  'turaif',
#  'hadibu',
#  'stanley',
#  'punta arenas',
#  'general ramirez',
#  'hamilton',
#  'vilyuchinsk',
#  'ambon',
#  'longyearbyen',
#  'pindi gheb',
#  'bilibino',
#  'thompson',
#  'dunedin',
#  'shindand',
#  'qaqortoq',
#  'brookings',
#  'sigli',
#  'prieska',
#  'irara',
#  'tokar',
#  'noumea',
#  'santa elena de uairen',
#  'rio gallegos',
#  'utrik',
#  'kerikeri',
#  "kapa'a",
#  'egilsstadir',
#  'misratah',
#  'abalak',
#  'ceeldheer',
#  'atafu village',
#  'shenjiamen',
#  'cabo san lucas',
#  'kavieng',
#  'san borja',
#  'kamyaran',
#  'sehore',
#  'west island',
#  'meulaboh',
#  'tucurui',
#  'jamestown',
#  'shakhtersk',
#  'hermanus',
#  'askoy',
#  'miquelon',
#  'bereeda',
#  'arraial do cabo',
#  'murzuq',
#  'mili',
#  'kruisfontein',
#  'nemuro',
#  'keflavik',
#  'concepcion',
#  'forster',
#  'enoch',
#  'hundested',
#  'mata-utu',
#  'machico',
#  "'ohonua",
#  'motul',
#  'dexter',
#  'whitehorse',
#  'puerto ayora',
#  'pangai',
#  'globe',
#  'dryden',
#  'hotan',
#  'susuman',
#  'plettenberg bay',
#  'ciudad lazaro cardenas',
#  'veraval',
#  'saint-joseph',
#  'tanki leendert',
#  'rajpur',
#  'north bend',
#  'selfoss',
#  'tura',
#  'tindouf',
#  'ushuaia',
#  'brzeg dolny',
#  'san luis',
#  'ondjiva',
#  "st. john's",
#  'krasnyy kholm',
#  'neryungri',
#  'bredasdorp',
#  'qamdo',
#  'pitangueiras',
#  'aykhal',
#  'coyhaique',
#  'alofi',
#  'laela',
#  'kingston',
#  'carnarvon',
#  'kirensk',
#  'chibougamau',
#  'fuglafjordur',
#  'fort mcmurray',
#  'bir hadaj',
#  'nago',
#  'talnakh',
#  'lompoc',
#  'savave village',
#  'ixtapa',
#  'tolanaro',
#  'lev tolstoy',
#  'an nuhud',
#  'nadi',
#  'senahu',
#  'port glaud',
#  'sitka',
#  'el nido',
#  'luderitz',
#  'oranjemund',
#  'newman',
#  'preobrazheniye',
#  'la foa',
#  'cestos city',
#  'savoy',
#  'vila franca do campo',
#  'chinde',
#  'saipan',
#  'kudahuvadhoo',
#  'choibalsan',
#  'ojinaga',
#  'ancud',
#  'yarmouth',
#  'cannonvale',
#  'aleysk',
#  'chimore',
#  'island harbour',
#  'remire-montjoly',
#  'luena',
#  'chonchi',
#  'mulanje',
#  'kangding',
#  'mahibadhoo',
#  'nuuk',
#  'port macquarie',
#  'ad douiem',
#  'new norfolk',
#  'narimanov',
#  'linkou',
#  'anadyr',
#  'hasaki',
#  'meiktila',
#  'bushehr',
#  'isafjordur',
#  'edd',
#  'monte cristo',
#  'ola',
#  'tiksi',
#  'simiti',
#  'srandakan',
#  'warrnambool',
#  'jodiya bandar',
#  'itamarandiba',
#  'aasiaat',
#  'port alfred',
#  'lamu',
#  'yeppoon',
#  "hayma'",
#  'shubarkuduk',
#  'oppdal',
#  'kataragama',
#  'metlili chaamba',
#  'shalqar',
#  'kingscliff',
#  'quellon',
#  'port elizabeth',
#  'iskateley',
#  'san vicente de canete',
#  'puerto santa',
#  'puerto aysen',
#  'callao',
#  'kidal',
#  'saint-philippe',
#  'udachny',
#  'la ronge',
#  'smithers',
#  'chany',
#  'quang ngai',
#  'usogorsk',
#  'warmbad',
#  'melfort',
#  'sosnovo-ozerskoye',
#  'mawu',
#  'old town',
#  'monrovia',
#  'margate',
#  "nar'yan-mar",
#  'afaahiti',
#  'cockburn town',
#  'siocon',
#  'taiohae',
#  'flying fish cove',
#  'ust-nera',
#  'antsiranana',
#  'flin flon',
#  'yuli',
#  'muang khong',
#  'kitama',
#  'hell-ville',
#  'chilliwack',
#  'hazard',
#  'bonthe',
#  'taishan',
#  'zhangye',
#  'andovoranto',
#  'seminole',
#  'fitzgerald',
#  'mount gambier',
#  'san antonio de pale',
#  'gorontalo',
#  'leh',
#  'lazaro cardenas',
#  'marquette',
#  'rongelap',
#  'richfield',
#  'constitucion',
#  'kotlas',
#  'christiana',
#  'jabat',
#  'gordonvale',
#  'korla',
#  'ongjin',
#  'kanggye',
#  'birjand',
#  'devils lake',
#  'crane',
#  'igarka',
#  'malango',
#  'argo',
#  'villa gesell',
#  'la passe',
#  "val-d'or",
#  'usinsk',
#  'swan hill',
#  'alice springs',
#  'polyarnyy',
#  'parry sound',
#  'santiago de cao',
#  'vingt cinq',
#  'khandyga',
#  'new plymouth',
#  'kulhudhuffushi',
#  'macon',
#  'viljoenskroon',
#  'howard springs',
#  'pangody',
#  'pacific grove',
#  'abu jibeha',
#  'goianesia',
#  'puerto armuelles',
#  'midvagur',
#  'khash',
#  'cangzhou',
#  'walvis bay',
#  'taos',
#  'camana',
#  'vylkove',
#  'constantia',
#  'chadron',
#  'petauke',
#  'fuvahmulah',
#  'pariaman',
#  'tazovsky',
#  'sechura',
#  'little cayman',
#  'ghadamis',
#  'mugia',
#  'northam',
#  'boa vista',
#  'wauchope',
#  'hithadhoo',
#  'alexandria',
#  'itoman',
#  'tomatlan',
#  'neiafu',
#  'puerto san carlos',
#  'broken hill',
#  'auki',
#  'alotau',
#  'laguna',
#  'aitape',
#  'cargados carajos',
#  'forbes',
#  'inhambane',
#  'klyuchi',
#  'paradera',
#  'luganville',
#  'mochudi',
#  'tangalle',
#  'basco',
#  'leava',
#  'rikaze',
#  'kununurra',
#  'bamboo flat',
#  'al kharijah',
#  'kalmunai',
#  'berdigestyakh',
#  'mbale',
#  'as sulayyil',
#  'mumbwa',
#  'pokhara',
#  'tsiombe',
#  'massawa',
#  'bayan nur',
#  'howrah',
#  'vorkuta',
#  "ha'il",
#  'champerico',
#  'damghan',
#  'huarmey',
#  'ciutadella',
#  'morehead city',
#  'coari',
#  'tazacorte',
#  'douz',
#  "kamen'-rybolov",
#  'soc trang',
#  'santo antonio',
#  'gejiu',
#  'nanticoke',
#  'homer',
#  'lata',
#  'kailua-kona',
#  'parakou',
#  'fale old settlement',
#  'kone',
#  'bucu',
#  'corlu',
#  'olinda',
#  'placido de castro',
#  'deqen',
#  'bokhan',
#  'san rafael',
#  'lorengau',
#  'odessa',
#  "n'zeto",
#  'mount isa',
#  'outjo',
#  'mokhsogollokh',
#  'pisco',
#  'bowen',
#  'prince george',
#  'taltal',
#  'onega',
#  'kristiansund',
#  'chernyshevsk',
#  'rio grande',
#  'akureyri',
#  'east ballina',
#  'enewetak',
#  'alcudia',
#  'aleksandrovskoye',
#  'presidente dutra',
#  'as salamiyah',
#  'tranovaho',
#  'zaraza',
#  'greymouth',
#  'cururupu',
#  'labasa',
#  'colares',
#  'nyagan',
#  'chegdomyn',
#  'long beach',
#  'urangan',
#  'lagrange',
#  'klaksvik',
#  'emmett',
#  'katsuura',
#  'port blair',
#  'zaragoza',
#  'tossa de mar',
#  'shalazhi',
#  'namsos',
#  'bathsheba',
#  'nagqu',
#  'saint-pierre',
#  'el granada',
#  'cidreira',
#  'saldanha',
#  'albertina',
#  'hudson',
#  'bati',
#  'guerrero negro',
#  'revelstoke',
#  'casino',
#  'mungwi',
#  'ta`u',
#  'san mariano',
#  'huilong',
#  'freetown',
#  'bekondo',
#  'el calafate',
#  'ejido benito juarez',
#  'rialma',
#  'bubaque',
#  'vangaindrano',
#  'grantsville',
#  'tommot',
#  'weihai',
#  'jackson',
#  "yur'yevets",
#  'al hufuf',
#  'zyryanskoye',
#  'canutama',
#  "la'ie",
#  'silkeborg',
#  'aljezur',
#  'castelli',
#  'kirakira',
#  'ekangala',
#  'santa vitoria do palmar',
#  'fortuna',
#  'boise',
#  'zaysan',
#  'bakanas',
#  'grabo',
#  'baihe',
#  'sinabang',
#  'antsirabe afovoany',
#  'port lincoln',
#  'iwanai',
#  'humaita',
#  'ponta delgada',
#  'sars',
#  'port alberni',
#  'rockland',
#  "ust'-ilimsk",
#  'bokovskaya',
#  'djambala',
#  'vila do maio',
#  'sampacho',
#  'esikhaleni',
#  'myeik',
#  'axim',
#  'puerto baquerizo moreno',
#  "muzayri'",
#  'jutai',
#  'nova vicosa',
#  'punta del este',
#  'prince rupert',
#  'kill devil hills',
#  'piti village',
#  'tranas',
#  'grand falls-windsor',
#  'altamont',
#  'aligudarz',
#  'netanya',
#  'hakui',
#  'ordynskoye',
#  'peace river',
#  'pleiku',
#  'neyriz',
#  'tutong',
#  'sao gabriel da cachoeira',
#  'kayangel',
#  'mandalgovi',
#  'san patricio',
#  'yuzhno-kurilsk',
#  'hilo',
#  'gebeit',
#  'raikot',
#  'vieste',
#  'turinskaya sloboda',
#  'paphos',
#  'dwarka',
#  'sao joao da barra',
#  'siwa oasis',
#  'caleta de carquin',
#  'jogeva',
#  'bandarbeyla',
#  'kristinestad',
#  'winnemucca',
#  'kultali',
#  'mananara',
#  'capayan',
#  'illizi',
#  'sabha',
#  'rice lake',
#  'wanning',
#  'papao',
#  'as safirah',
#  'damaturu',
#  'belmonte',
#  'nadym',
#  'port augusta',
#  'shetpe',
#  'zakamensk',
#  'daru',
#  'st anne',
#  'padang',
#  'labrador city',
#  'salalah',
#  'binkolo',
#  'sundsvall',
#  'mogadishu',
#  'porto novo',
#  'mbalmayo',
#  'chissamba',
#  'richards bay',
#  'vanino',
#  'puerto gaitan',
#  'taoudenni',
#  'anahuac',
#  'ayvacik',
#  'holualoa',
#  'essaouira',
#  'port douglas',
#  'fort st. john',
#  'beira']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url +'&q=san francisco')
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=88959935e5b3e71115c002a0e0c684d0&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    #time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | enkoping
# Processing Record 2 of Set 1 | badger
# Processing Record 3 of Set 1 | hawaiian paradise park
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | kapuskasing
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | minas de marcona
# Processing Record 8 of Set 1 | jindabyne
# Processing Record 9 of Set 1 | brainerd
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | invercargill
# Processing Record 14 of Set 1 | college
# Processing Record 15 of Set 1 | juegang
# Processing Record 16 of Set 1 | olonkinbyen
# Processing Record 17 of Set 1 | lihue
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | dudinka
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | sola
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | filadelfia
# Processing Record 25 of Set 1 | laojunmiao
# Processing Record 26 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 1 | vrangel'
# Processing Record 28 of Set 1 | nova sintra
# Processing Record 29 of Set 1 | slivnitsa
# Processing Record 30 of Set 1 | wailua homesteads
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | grytviken
# Processing Record 33 of Set 1 | papatowai
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | manturovo
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 
# Processing Record 38 of Set 4 | choibalsan
# Processing Record 39 of Set 4 | ojinaga
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | yarmouth
# Processing Record 42 of Set 4 | cannonvale
# Processing Record 43 of Set 4 | aleysk
# Processing Record 44 of Set 4 | chimore
# Processing Record 45 of Set 4 | island harbour
# Processing Record 46 of Set 4 | remire-montjoly
# Processing Record 47 of Set 4 | luena
# Processing Record 48 of Set 4 | chonchi
# Processing Record 49 of Set 4 | mulanje
# Processing Record 0 of Set 5 | kangding
# Processing Record 1 of Set 5 | mahibadhoo
# Processing Record 2 of Set 5 | nuuk
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | ad douiem
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | narimanov
# Processing Record 7 of Set 5 | linkou
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | meiktila
# Processing Record 11 of Set 5 | bushehr
# Processing Record 12 of Set 5 | isafjordur
# Processing Record 13 of Set 5 | edd
# Processing Record 14 of Set 5 | monte cristo
# Processing Record 15 of Set 5 | ola
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | simiti
# Processing Record 18 of Set 5 | srandakan
# Processing Record 19 of Set 5 | warrnambool
# Processing Record 20 of Set 5 | jodiya bandar
# Processing Record 21 of Set 5 | itamarandiba
# Processing Record 22 of Set 5 | aasiaat
# Processing Record 23 of Set 5 | port alfred
# Processing Record 24 of Set 5 | lamu
# Processing Record 25 of Set 5 | yeppoon
# Processing Record 26 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 5 | shubarkuduk
# Processing Record 28 of Set 5 | oppdal
# Processing Record 29 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 30 of Set 5 | metlili chaamba
# Processing Record 31 of Set 5 | shalqar
# Processing Record 32 of Set 5 | kingscliff
# Processing Record 33 of Set 5 | quellon
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | iskateley
# Processing Record 36 of Set 5 | san vicente de canete
# Processing Record 37 of Set 5 | puerto santa
# Processing Record 38 of Set 5 | puerto aysen
# Processing Record 39 of Set 5 | callao
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | udachny
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | smithers
# Processing Record 45 of Set 5 | chany
# Processing Record 46 of Set 5 | quang ngai
# Processing Record 47 of Set 5 | usogorsk
# Processing Record 48 of Set 5 | warmbad
# Processing Record 49 of Set 5 | melfort
# Processing Record 0 of Set 6 | sosnovo-ozerskoye
# Processing Record 1 of Set 6 | mawu
# Processing Record 2 of Set 6 | old town
# Processing Record 3 of Set 6 | monrovia
# Processing Record 4 of Set 6 | margate
# Processing Record 5 of Set 6 | nar'yan-mar
# Processing Record 6 of Set 6 | afaahiti
# Processing Record 7 of Set 6 | cockburn town
# Processing Record 8 of Set 6 | siocon
# Processing Record 9 of Set 6 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 6 | flying fish cove
# Processing Record 11 of Set 6 | ust-nera
# Processing Record 12 of Set 6 | antsiranana
# Processing Record 13 of Set 6 | flin flon
# Processing Record 14 of Set 6 | yuli
# Processing Record 15 of Set 6 | muang khong
# Processing Record 16 of Set 6 | kitama
# Processing Record 17 of Set 6 | hell-ville
# Processing Record 18 of Set 6 | chilliwack
# Processing Record 19 of Set 6 | hazard
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | taishan
# Processing Record 22 of Set 6 | zhangye
# Processing Record 23 of Set 6 | andovoranto
# Processing Record 24 of Set 6 | seminole
# Processing Record 25 of Set 6 | fitzgerald
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | san antonio de pale
# Processing Record 28 of Set 6 | gorontalo
# Processing Record 29 of Set 6 | leh
# Processing Record 30 of Set 6 | lazaro cardenas
# Processing Record 31 of Set 6 | marquette
# Processing Record 32 of Set 6 | rongelap
# Processing Record 33 of Set 6 | richfield
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | kotlas
# Processing Record 36 of Set 6 | christiana
# Processing Record 37 of Set 6 | jabat
# Processing Record 38 of Set 6 | gordonvale
# Processing Record 39 of Set 6 | korla
# Processing Record 40 of Set 6 | ongjin
# Processing Record 41 of Set 6 | kanggye
# Processing Record 42 of Set 6 | birjand
# Processing Record 43 of Set 6 | devils lake
# Processing Record 44 of Set 6 | crane
# Processing Record 45 of Set 6 | igarka
# Processing Record 46 of Set 6 | malango
# Processing Record 47 of Set 6 | argo
# Processing Record 48 of Set 6 | villa gesell
# Processing Record 49 of Set 6 | la passe
# Processing Record 0 of Set 7 | val-d'or
# Processing Record 1 of Set 7 | usinsk
# Processing Record 2 of Set 7 | swan hill
# Processing Record 3 of Set 7 | alice springs
# Processing Record 4 of Set 7 | polyarnyy
# Processing Record 5 of Set 7 | parry sound
# Processing Record 6 of Set 7 | santiago de cao
# Processing Record 7 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 8 of Set 7 | khandyga
# Processing Record 9 of Set 7 | new plymouth
# Processing Record 10 of Set 7 | kulhudhuffushi
# Processing Record 11 of Set 7 | macon
# Processing Record 12 of Set 7 | viljoenskroon
# Processing Record 13 of Set 7 | howard springs
# Processing Record 14 of Set 7 | pangody
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | abu jibeha
# Processing Record 17 of Set 7 | goianesia
# Processing Record 18 of Set 7 | puerto armuelles
# Processing Record 19 of Set 7 | midvagur
# Processing Record 20 of Set 7 | khash
# Processing Record 21 of Set 7 | cangzhou
# Processing Record 22 of Set 7 | walvis bay
# Processing Record 23 of Set 7 | taos
# Processing Record 24 of Set 7 | camana
# Processing Record 25 of Set 7 | vylkove
# Processing Record 26 of Set 7 | constantia
# Processing Record 27 of Set 7 | chadron
# Processing Record 28 of Set 7 | petauke
# Processing Record 29 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record
# Processing Record 7 of Set 9 | mokhsogollokh
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | bowen
# Processing Record 10 of Set 9 | prince george
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | onega
# Processing Record 13 of Set 9 | kristiansund
# Processing Record 14 of Set 9 | chernyshevsk
# Processing Record 15 of Set 9 | rio grande
# Processing Record 16 of Set 9 | akureyri
# Processing Record 17 of Set 9 | east ballina
# Processing Record 18 of Set 9 | enewetak
# Processing Record 19 of Set 9 | alcudia
# Processing Record 20 of Set 9 | aleksandrovskoye
# Processing Record 21 of Set 9 | presidente dutra
# Processing Record 22 of Set 9 | as salamiyah
# Processing Record 23 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 9 | zaraza
# Processing Record 25 of Set 9 | greymouth
# Processing Record 26 of Set 9 | cururupu
# Processing Record 27 of Set 9 | labasa
# Processing Record 28 of Set 9 | colares
# Processing Record 29 of Set 9 | nyagan
# Processing Record 30 of Set 9 | chegdomyn
# Processing Record 31 of Set 9 | long beach
# Processing Record 32 of Set 9 | urangan
# Processing Record 33 of Set 9 | lagrange
# Processing Record 34 of Set 9 | klaksvik
# Processing Record 35 of Set 9 | emmett
# Processing Record 36 of Set 9 | katsuura
# Processing Record 37 of Set 9 | port blair
# Processing Record 38 of Set 9 | zaragoza
# Processing Record 39 of Set 9 | tossa de mar
# Processing Record 40 of Set 9 | shalazhi
# Processing Record 41 of Set 9 | namsos
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | nagqu
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | el granada
# Processing Record 46 of Set 9 | cidreira
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | albertina
# Processing Record 49 of Set 9 | hudson
# Processing Record 0 of Set 10 | bati
# Processing Record 1 of Set 10 | guerrero negro
# Processing Record 2 of Set 10 | revelstoke
# Processing Record 3 of Set 10 | casino
# Processing Record 4 of Set 10 | mungwi
# Processing Record 5 of Set 10 | ta`u
# Processing Record 6 of Set 10 | san mariano
# Processing Record 7 of Set 10 | huilong
# Processing Record 8 of Set 10 | freetown
# Processing Record 9 of Set 10 | bekondo
# Processing Record 10 of Set 10 | el calafate
# Processing Record 11 of Set 10 | ejido benito juarez
# City not found. Skipping...
# Processing Record 12 of Set 10 | rialma
# Processing Record 13 of Set 10 | bubaque
# Processing Record 14 of Set 10 | vangaindrano
# Processing Record 15 of Set 10 | grantsville
# Processing Record 16 of Set 10 | tommot
# Processing Record 17 of Set 10 | weihai
# Processing Record 18 of Set 10 | jackson
# Processing Record 19 of Set 10 | yur'yevets
# Processing Record 20 of Set 10 | al hufuf
# Processing Record 21 of Set 10 | zyryanskoye
# Processing Record 22 of Set 10 | canutama
# Processing Record 23 of Set 10 | la'ie
# Processing Record 24 of Set 10 | silkeborg
# Processing Record 25 of Set 10 | aljezur
# Processing Record 26 of Set 10 | castelli
# Processing Record 27 of Set 10 | kirakira
# Processing Record 28 of Set 10 | ekangala
# Processing Record 29 of Set 10 | santa vitoria do palmar
# Processing Record 30 of Set 10 | fortuna
# Processing Record 31 of Set 10 | boise
# Processing Record 32 of Set 10 | zaysan
# Processing Record 33 of Set 10 | bakanas
# Processing Record 34 of Set 10 | grabo
# Processing Record 35 of Set 10 | baihe
# Processing Record 36 of Set 10 | sinabang
# Processing Record 37 of Set 10 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 38 of Set 10 | port lincoln
# Processing Record 39 of Set 10 | iwanai
# Processing Record 40 of Set 10 | humaita
# Processing Record 41 of Set 10 | ponta delgada
# Processing Record 42 of Set 10 | sars
# Processing Record 43 of Set 10 | port alberni
# Processing Record 44 of Set 10 | rockland
# Processing Record 45 of Set 10 | ust'-ilimsk
# Processing Record 46 of Set 10 | bokovskaya
# Processing Record 47 of Set 10 | djambala
# Processing Record 48 of Set 10 | vila do maio
# Processing Record 49 of Set 10 | sampacho
# Processing Record 0 of Set 11 | esikhaleni
# Processing Record 1 of Set 11 | myeik
# Processing Record 2 of Set 11 | axim
# Processing Record 3 of Set 11 | puerto baquerizo moreno
# Processing Record 4 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 5 of Set 11 | jutai
# Processing Record 6 of Set 11 | nova vicosa
# Processing Record 7 of Set 11 | punta del este
# Processing Record 8 of Set 11 | prince rupert
# Processing Record 9 of Set 11 | kill devil hills
# Processing Record 10 of Set 11 | piti village
# Processing Record 11 of Set 11 | tranas
# Processing Record 12 of Set 11 | grand falls-windsor
# Processing Record 13 of Set 11 | altamont
# Processing Record 14 of Set 11 | aligudarz
# Processing Record 15 of Set 11 | netanya
# Processing Record 16 of Set 11 | hakui
# Processing Record 17 of Set 11 | ordynskoye
# Processing Record 18 of Set 11 | peace river
# Processing Record 19 of Set 11 | pleiku
# Processing Record 20 of Set 11 | neyriz
# Processing Record 21 of Set 11 | tutong
# Processing Record 22 of Set 11 | sao gabriel da cachoeira
# Processing Record 23 of Set 11 | kayangel
# Processing Record 24 of Set 11 | mandalgovi
# Processing Record 25 of Set 11 | san patricio
# Processing Record 26 of Set 11 | yuzhno-kurilsk
# Processing Record 27 of Set 11 | hilo
# Processing Record 28 of Set 11 | gebeit
# Processing Record 29 of Set 11 | raikot
# Processing Record 30 of Set 11 | vieste
# Processing Record 31 of Set 11 | turinskaya sloboda
# Processing Record 32 of Set 11 | paphos
# Processing Record 33 of Set 11 | dwarka
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | siwa oasis
# Processing Record 36 of Set 11 | caleta de carquin
# Processing Record 37 of Set 11 | jogeva
# Processing Record 38 of Set 11 | bandarbeyla
# Processing Record 39 of Set 11 | kristinestad
# Processing Record 40 of Set 11 | winnemucca
# Processing Record 41 of Set 11 | kultali
# City not found. Skipping...
# Processing Record 42 of Set 11 | mananara
# Processing Record 43 of Set 11 | capayan
# Processing Record 44 of Set 11 | illizi
# Processing Record 45 of Set 11 | sabha
# Processing Record 46 of Set 11 | rice lake
# Processing Record 47 of Set 11 | wanning
# Processing Record 48 of Set 11 | papao
# Processing Record 49 of Set 11 | as safirah
# Processing Record 0 of Set 12 | damaturu
# Processing Record 1 of Set 12 | belmonte
# Processing Record 2 of Set 12 | nadym
# Processing Record 3 of Set 12 | port augusta
# Processing Record 4 of Set 12 | shetpe
# Processing Record 5 of Set 12 | zakamensk
# Processing Record 6 of Set 12 | daru
# Processing Record 7 of Set 12 | st anne
# Processing Record 8 of Set 12 | padang
# Processing Record 9 of Set 12 | labrador city
# Processing Record 10 of Set 12 | salalah
# Processing Record 11 of Set 12 | binkolo
# Processing Record 12 of Set 12 | sundsvall
# Processing Record 13 of Set 12 | mogadishu
# Processing Record 14 of Set 12 | porto novo
# Processing Record 15 of Set 12 | mbalmayo
# Processing Record 16 of Set 12 | chissamba
# Processing Record 17 of Set 12 | richards bay
# Processing Record 18 of Set 12 | vanino
# Processing Record 19 of Set 12 | puerto gaitan
# Processing Record 20 of Set 12 | taoudenni
# Processing Record 21 of Set 12 | anahuac
# Processing Record 22 of Set 12 | ayvacik
# Processing Record 23 of Set 12 | holualoa
# Processing Record 24 of Set 12 | essaouira
# Processing Record 25 of Set 12 | port douglas
# Processing Record 26 of Set 12 | fort st. john
# Processing Record 27 of Set 12 | beira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness
# 0                enkoping  59.6361   17.0777     23.02        59          48  \
# 1                  badger  64.8000 -147.5333     13.33        79          75
# 2  hawaiian paradise park  19.5933 -154.9731     22.72        97         100
# 3               adamstown -25.0660 -130.1015     22.01        83          77
# 4             kapuskasing  49.4169  -82.4331     27.52        59          95
#
#    Wind Speed Country        Date
# 0        3.35      SE  1722362940
# 1        2.57      US  1722362836
# 2        2.57      US  1722362792
# 3        8.42      PN  1722362767
# 4        0.15      CA  1722362941

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity
# City_ID
# 0                      enkoping  59.6361   17.0777     23.02        59  \
# 1                        badger  64.8000 -147.5333     13.33        79
# 2        hawaiian paradise park  19.5933 -154.9731     22.72        97
# 3                     adamstown -25.0660 -130.1015     22.01        83
# 4                   kapuskasing  49.4169  -82.4331     27.52        59
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                48        3.35      SE  1722362940
# 1                75        2.57      US  1722362836
# 2               100        2.57      US  1722362792
# 3                77        8.42      PN  1722362767
# 4                95        0.15      CA  1722362941

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import time

# Build scatter plot for latitude vs. temperature


plt.scatter(city_data_df['Lat'],
           city_data_df['Max Temp'],edgecolor='r',
            linewidth=1,
            marker='o',
            alpha=0.8,label='cities')

# Incorporate the other graph properties
date = time.strftime('%y-%m-%d')

plt.title(f"city max latitude vs temperature (%s) ({date})")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(C)')


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],
           city_data_df['Humidity'],edgecolor='orange',
            linewidth=1,
            marker='o',
            alpha=0.8,label='cities')

# Incorporate the other graph properties
date = time.strftime('%y-%m-%d')

plt.title(f"city max latitude vs Humididty ({date})")
plt.xlabel('Latitude')
plt.ylabel('humidity(%)')


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],
           city_data_df['Cloudiness'],edgecolor='blue',
            linewidth=1,
            marker='o',
            alpha=0.8,label='cities')

# Incorporate the other graph properties
date = time.strftime('%y-%m-%d')

plt.title(f"city max latitude vs Cloudiness ({date})")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],
           city_data_df['Wind Speed'],edgecolor='green',
            linewidth=1,
            marker='o',
            alpha=0.8,label='cities')


# Incorporate the other graph properties
date = time.strftime('%y-%m-%d')

plt.title(f"city max latitude vs Wind Speed ({date})")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(%)')


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x +{round(intercept,2)}"

    plt.scatter(x_value,y_value)
    plt.plot(x_value, regress_value, 'r-')
    plt.annotate(line_eq, text_coord, fontsize=15, color = 'r')
    plt.xlabel('lat')
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df['Lat']>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity
# City_ID
# 0                      enkoping  59.6361   17.0777     23.02        59  \
# 1                        badger  64.8000 -147.5333     13.33        79
# 2        hawaiian paradise park  19.5933 -154.9731     22.72        97
# 4                   kapuskasing  49.4169  -82.4331     27.52        59
# 8                      brainerd  46.3580  -94.2008     28.33        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                48        3.35      SE  1722362940
# 1                75        2.57      US  1722362836
# 2               100        2.57      US  1722362792
# 4                95        0.15      CA  1722362941
# 8                 0        3.09      US  1722362942

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df['Lat']<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 3                adamstown -25.0660 -130.1015     22.01        83          77  \
# 5               codrington -38.2667  141.9667      5.10        92          17
# 6         minas de marcona -15.2119  -75.1103     18.56        47           0
# 7                jindabyne -36.4167  148.6333     -0.79        93          14
# 9        port-aux-francais -49.3500   70.2167      2.98        94          99
#
#          Wind Speed Country        Date
# City_ID
# 3              8.42      PN  1722362767
# 5              3.25      AU  1722362941
# 6              4.34      PE  1722362786
# 7              1.87      AU  1722362941
# 9             12.90      TF  1722362768

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp', (6, -10))
# Out:
# The r-value is 0.3569048326277338

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55, 5))
# Out:
# The r-value is 0.696341660277443

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(6, -10))
# Out:
# The r-value is 0.00011629679253358075

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55, 5))
# Out:
# The r-value is 0.696341660277443

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(6, -10))
# Out:
# The r-value is 0.00011629679253358075

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55, 5))
# Out:
# The r-value is 0.696341660277443

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(6, -10))
# Out:
# The r-value is 0.00011629679253358075

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55, 5))
# Out:
# The r-value is 0.696341660277443

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
The Python API Challenge WeatherPy part discusses linear relationships by computing linear regression for 
various weather parameters and latitudes across the Northern and Southern Hemispheres.
As part of this process, scatter plots are created for different pairs of variables, such as temperature,
humidity, cloudiness, and wind speed against latitude. An analysis of linear regression is helpful in understanding 
the relationship between weather parameters and latitude in each hemisphere.
We aim to visualize and interpret how these parameters change as one moves closer to or farther from the equator.
